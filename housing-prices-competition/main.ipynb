# %%
import warnings

warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from xgboost import XGBRegressor

# %%
pd.set_option("display.max_columns", 100)
pd.set_option("display.max_rows", 100)

# %%
df_train = pd.read_csv("../dataset/housing-prices-competition/train.csv")
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape LandContour Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType SaleCondition  SalePrice
# ...

# %%
df_test = pd.read_csv("../dataset/housing-prices-competition/test.csv")
df_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape LandContour Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType SaleCondition
# ...

# %% [markdown]
# # Data Exploration

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df_train.isna().sum()[df_train.isna().sum() > 0]
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType       872
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
df_train[df_train["GarageType"].isna()][
    [
        "GarageType",
        "GarageYrBlt",
        "GarageFinish",
        "GarageCars",
        "GarageArea",
        "GarageQual",
        "GarageCond",
    ]
].head()
# Out:
#    GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond
# 39        NaN          NaN          NaN           0           0        NaN        NaN
# 48        NaN          NaN          NaN           0           0        NaN        NaN
# 78        NaN          NaN          NaN           0           0        NaN        NaN
# 88        NaN          NaN          NaN           0           0        NaN        NaN
# 89        NaN          NaN          NaN           0           0        NaN        NaN

# %%
df_train["MiscFeature"].value_counts()
# Out:
# MiscFeature
# Shed    49
# Gar2     2
# Othr     2
# TenC     1
# Name: count, dtype: int64

# %%
df_train["Fence"].value_counts()
# Out:
# Fence
# MnPrv    157
# GdPrv     59
# GdWo      54
# MnWw      11
# Name: count, dtype: int64

# %%
df_train["Electrical"].value_counts()
# Out:
# Electrical
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: count, dtype: int64

# %%
df_train["PoolQC"].value_counts()
# Out:
# PoolQC
# Gd    3
# Ex    2
# Fa    2
# Name: count, dtype: int64

# %%
df_train["FireplaceQu"].value_counts()
# Out:
# FireplaceQu
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: count, dtype: int64

# %%
df_train[df_train["BsmtQual"].isna()][
    [
        "BsmtQual",
        "BsmtCond",
        "BsmtExposure",
        "BsmtFinType1",
        "BsmtFinType2",
        "BsmtFinSF1",
        "BsmtFinSF2",
        "BsmtUnfSF",
        "TotalBsmtSF",
    ]
].head()
# Out:
#     BsmtQual BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF
# 17       NaN      NaN          NaN          NaN          NaN           0           0          0            0
# 39       NaN      NaN          NaN          NaN          NaN           0           0          0            0
# 90       NaN      NaN          NaN          NaN          NaN           0           0          0            0
# 102      NaN      NaN          NaN          NaN          NaN           0           0          0            0
# 156      NaN      NaN          NaN          NaN          NaN           0           0          0            0

# %%
df_train["LotFrontage"].describe()
# Out:
# count    1201.000000
# mean       70.049958
# std        24.284752
# min        21.000000
# 25%        59.000000
# 50%        69.000000
# 75%        80.000000
# max       313.000000
# Name: LotFrontage, dtype: float64

# %%
df_train["Alley"].value_counts()
# Out:
# Alley
# Grvl    50
# Pave    41
# Name: count, dtype: int64

# %%
df_train["MasVnrType"].value_counts()
# Out:
# MasVnrType
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: count, dtype: int64

# %%
df_train["MasVnrArea"].describe()
# Out:
# count    1452.000000
# mean      103.685262
# std       181.066207
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       166.000000
# max      1600.000000
# Name: MasVnrArea, dtype: float64

# %%
df_test.isna().sum()[df_test.isna().sum() > 0]
# Out:
# MSZoning           4
# LotFrontage      227
# Alley           1352
# Utilities          2
# Exterior1st        1
# Exterior2nd        1
# MasVnrType       894
# MasVnrArea        15
# BsmtQual          44
# BsmtCond          45
# BsmtExposure      44
# BsmtFinType1      42
# BsmtFinSF1         1
# BsmtFinType2      42
# BsmtFinSF2         1
# BsmtUnfSF          1
# TotalBsmtSF        1
# BsmtFullBath       2
# BsmtHalfBath       2
# KitchenQual        1
# Functional         2
# FireplaceQu      730
# GarageType        76
# GarageYrBlt       78
# GarageFinish      78
# GarageCars         1
# GarageArea         1
# GarageQual        78
# GarageCond        78
# PoolQC          1456
# Fence           1169
# MiscFeature     1408
# SaleType           1
# dtype: int64

# %% [markdown]
# # Prepare Data

# %%
constant_cols = [
    "Fence",
    "Alley",
    "MiscFeature",
    "PoolQC",
    "FireplaceQu",
    "GarageType",
    "GarageFinish",
    "GarageQual",
    "GarageCond",
    "BsmtQual",
    "BsmtCond",
    "BsmtExposure",
    "BsmtFinType1",
    "BsmtFinType2",
]

cat_cols = [
    col
    for col in df_train.select_dtypes(include="object").columns
    if col not in constant_cols + ["Electrical", "MasVnrType"]
]

num_cols = df_train.select_dtypes(include=["int64", "float64"]).columns.drop(
    ["SalePrice", "GarageYrBlt", "GarageCars", "GarageArea", "Id"]
)

electrical_pipeline = Pipeline(
    steps=[
        ("imputer", SimpleImputer(strategy="constant", fill_value="SBrkr")),
        ("onehot", OneHotEncoder(drop="first", handle_unknown="ignore")),
    ]
)

masvnrtype_pipeline = Pipeline(
    steps=[
        ("imputer", SimpleImputer(strategy="constant", fill_value="None")),
        ("onehot", OneHotEncoder(drop="first", handle_unknown="ignore")),
    ]
)

garage_num_pipeline = Pipeline(
    steps=[("imputer", SimpleImputer(strategy="constant", fill_value=0))]
)

constant_pipeline = Pipeline(
    steps=[
        ("imputer", SimpleImputer(strategy="constant", fill_value="NA")),
        ("onehot", OneHotEncoder(drop="first", handle_unknown="ignore")),
    ]
)

categorical_pipeline = Pipeline(
    steps=[
        ("imputer", SimpleImputer(strategy="most_frequent")),
        ("onehot", OneHotEncoder(drop="first", handle_unknown="ignore")),
    ]
)

numeric_pipeline = Pipeline(
    steps=[("imputer", SimpleImputer(strategy="mean")), ("scaler", StandardScaler())]
)

preprocessor = ColumnTransformer(
    transformers=[
        ("electrical", electrical_pipeline, ["Electrical"]),
        ("masvnrtype", masvnrtype_pipeline, ["MasVnrType"]),
        (
            "garage_num",
            garage_num_pipeline,
            ["GarageYrBlt", "GarageCars", "GarageArea"],
        ),
        ("constant", constant_pipeline, constant_cols),
        ("cat", categorical_pipeline, cat_cols),
        ("num", numeric_pipeline, num_cols),
    ]
)

X_train = df_train.drop(columns=["Id", "SalePrice"])
y_train = df_train["SalePrice"]

X_train_transformed = preprocessor.fit_transform(X_train)
X_test_transformed = preprocessor.transform(df_test.drop(columns=["Id"]))

# %%
param_grid = {
    "n_estimators": [100, 200, 500],
    "learning_rate": [0.01, 0.05, 0.1, 0.2],
    "max_depth": [3, 5, 7, 10],
    "min_child_weight": [1, 3, 5],
    "subsample": [0.6, 0.8, 1.0],
    "colsample_bytree": [0.6, 0.8, 1.0],
    "gamma": [0, 0.1, 0.2, 0.3],
    "reg_alpha": [0, 0.1, 0.5, 1],
    "reg_lambda": [0, 0.1, 0.5, 1],
}

randomized_search = RandomizedSearchCV(
    estimator=XGBRegressor(random_state=42),
    param_distributions=param_grid,
    n_iter=50,
    cv=10,
    n_jobs=-1,
    verbose=2,
    scoring="neg_mean_squared_error",
    random_state=42,
)
randomized_search.fit(X_train_transformed, y_train)

best_score = np.sqrt(-randomized_search.best_score_)
print(f"Mean RMSE (CV): {best_score:.4f}")
# Out:
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Mean RMSE (CV): 25720.4981

# %%
model = randomized_search.best_estimator_
y_pred = model.predict(X_test_transformed)

submission = pd.DataFrame({"Id": df_test["Id"], "SalePrice": y_pred})
submission.to_csv("../dataset/housing-prices-competition/submission.csv", index=False)
